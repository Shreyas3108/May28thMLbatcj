# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/Shreyas3108/May28thMLbatcj/blob/master/Untitled8.ipynb)

# %%
import pandas as pd 
import numpy as np

# %%
# Series 
pd.Series([1,23])
# Out:
# 0     1
# 1    23
# dtype: int64

# %%
d = {'name':['Pooja' , 'Sudhanshu' , 'Deepak' , 'Karan' , 'Shrishti' , 'Sunny','Harjeevan' , 'Simran','Abhishek'] , 'number':['12' , 23 , 32 , 1 , 21 , 32 , 12 ,21 ,21]}

# %%
d
# Out:
# {'name': ['Pooja',
#   'Sudhanshu',
#   'Deepak',
#   'Karan',
#   'Shrishti',
#   'Sunny',
#   'Harjeevan',
#   'Simran',
#   'Abhishek'],
#  'number': ['12', 23, 32, 1, 21, 32, 12, 21, 21]}

# %% [markdown]
# ## Creation of DataFrame

# %% [markdown]
# Here we create a dataframe

# %%
index = ['1no','2no' , '3no' , '4no' , '5no' , '6no' , '7no' , '8np','9no']

# %%
-data = pd.DataFrame(d , index=index)

# %%
data[2:]
# Out:
#           name number
# 3no     Deepak     32
# 4no      Karan      1
# 5no   Shrishti     21
# 6no      Sunny     32
# 7no  Harjeevan     12
# 8np     Simran     21
# 9no   Abhishek     21

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv')

# %%
df.head() # First 5 rows
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.head(10)
# Out:
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1   11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2   11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3   11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4   11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5   11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6   11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7   11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8   11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9  11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# ...

# %%
df.describe(include = 'all')
# Out:
#              Date  Location     MinTemp     MaxTemp    Rainfall  Evaporation  \
# count         366       366  366.000000  366.000000  366.000000   366.000000
# unique        366         1         NaN         NaN         NaN          NaN
# top     4/15/2008  Canberra         NaN         NaN         NaN          NaN
# freq            1       366         NaN         NaN         NaN          NaN
# mean          NaN       NaN    7.265574   20.550273    1.428415     4.521858
# std           NaN       NaN    6.025800    6.690516    4.225800     2.669383
# min           NaN       NaN   -5.300000    7.600000    0.000000     0.200000
# 25%           NaN       NaN    2.300000   15.025000    0.000000     2.200000
# 50%           NaN       NaN    7.450000   19.650000    0.000000     4.200000
# 75%           NaN       NaN   12.500000   25.500000    0.200000     6.400000
# max           NaN       NaN   20.900000   35.800000   39.800000    13.800000
#
# ...

# %%
df.tail()
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 361  10/27/2008  Canberra      9.0     30.7       0.0          7.6      12.1
# 362  10/28/2008  Canberra      7.1     28.4       0.0         11.6      12.7
# 363  10/29/2008  Canberra     12.5     19.9       0.0          8.4       5.3
# 364  10/30/2008  Canberra     12.5     26.9       0.0          5.0       7.1
# 365  10/31/2008  Canberra     12.3     30.2       0.0          6.0      12.6
#
#     WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 361         NNW           76.0        SSE      ...               15
# 362           N           48.0        NNW      ...               22
# 363         ESE           43.0        ENE      ...               47
# 364          NW           46.0        SSW      ...               39
# 365          NW           78.0         NW      ...               13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# ...

# %%
df.iloc[:,1].describe(include = 'all')
# Out:
# count          366
# unique           1
# top       Canberra
# freq           366
# Name: Location, dtype: object

# %%
df['Location'].describe(include = 'all')
# Out:
# count          366
# unique           1
# top       Canberra
# freq           366
# Name: Location, dtype: object

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-d5ed7ae1-7326-4cde-baae-9fba2f9c328e" name="files[]" multiple disabled />
#      <output id="result-d5ed7ae1-7326-4cde-baae-9fba2f9c328e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Book1.xlsx to Book1.xlsx
# User uploaded file "Book1.xlsx" with length 9900 bytes

# %%
data1 = pd.read_excel('Book1.xlsx' , 0)

# %%
data1
# Out:
#           Name  Age  Interest_in_ML
# 0     Abhishek   19             5.0
# 1       Arjun    21             4.9
# 2        Bipin   20             4.5
# 3       Deepak   20             4.0
# 4    Harjeevan   21             4.5
# 5        Karan   19             4.5
# 6       Meghna   22            10.0
# 7        Pooja   20             5.0
# 8       Rahul    21             5.0
# 9     Shrishti   20             4.8
# 10      Simran   20             5.0
# 11  Sudhanshu    21             5.0
# 12       Sunny   20             5.0

# %%
data1.describe()
# Out:
#              Age  Interest_in_ML
# count  13.000000       13.000000
# mean   20.307692        5.169231
# std     0.854850        1.484017
# min    19.000000        4.000000
# 25%    20.000000        4.500000
# 50%    20.000000        5.000000
# 75%    21.000000        5.000000
# max    22.000000       10.000000

# %%
data1.loc[data1['Interest_in_ML'] <= 5]
# Out:
#           Name  Age  Interest_in_ML
# 0     Abhishek   19             5.0
# 1       Arjun    21             4.9
# 2        Bipin   20             4.5
# 3       Deepak   20             4.0
# 4    Harjeevan   21             4.5
# 5        Karan   19             4.5
# 7        Pooja   20             5.0
# 8       Rahul    21             5.0
# 9     Shrishti   20             4.8
# 10      Simran   20             5.0
# 11  Sudhanshu    21             5.0
# 12       Sunny   20             5.0

# %%
data1[data1['Interest_in_ML'] < 5.1]
# Out:
#           Name  Age  Interest_in_ML
# 0     Abhishek   19             5.0
# 1       Arjun    21             4.9
# 2        Bipin   20             4.5
# 3       Deepak   20             4.0
# 4    Harjeevan   21             4.5
# 5        Karan   19             4.5
# 7        Pooja   20             5.0
# 8       Rahul    21             5.0
# 9     Shrishti   20             4.8
# 10      Simran   20             5.0
# 11  Sudhanshu    21             5.0
# 12       Sunny   20             5.0

# %%
data2 = data1[data1['Name'] != 'Meghna']

# %%
data2.describe()
# Out:
#              Age  Interest_in_ML
# count  12.000000       12.000000
# mean   20.166667        4.766667
# std     0.717741        0.322866
# min    19.000000        4.000000
# 25%    20.000000        4.500000
# 50%    20.000000        4.950000
# 75%    21.000000        5.000000
# max    21.000000        5.000000

# %%
data1.loc[(data1['Name']!='Meghna') & (data1['Name']!='Harjeevan')]
# Out:
#           Name  Age  Interest_in_ML
# 0     Abhishek   19             5.0
# 1       Arjun    21             4.9
# 2        Bipin   20             4.5
# 3       Deepak   20             4.0
# 5        Karan   19             4.5
# 7        Pooja   20             5.0
# 8       Rahul    21             5.0
# 9     Shrishti   20             4.8
# 10      Simran   20             5.0
# 11  Sudhanshu    21             5.0
# 12       Sunny   20             5.0

# %%
data1.sum()
# Out:
# Name              AbhishekArjun BipinDeepakHarjeevanKaranMeghnaP...
# Age                                                             264
# Interest_in_ML                                                 67.2
# dtype: object

# %%
data1.iloc[1:3,:]
# Out:
#      Name  Age  Interest_in_ML
# 1  Arjun    21             4.9
# 2   Bipin   20             4.5

# %%
data1.iloc[:,:-1]
# Out:
#           Name  Age
# 0     Abhishek   19
# 1       Arjun    21
# 2        Bipin   20
# 3       Deepak   20
# 4    Harjeevan   21
# 5        Karan   19
# 6       Meghna   22
# 7        Pooja   20
# 8       Rahul    21
# 9     Shrishti   20
# 10      Simran   20
# 11  Sudhanshu    21
# 12       Sunny   20

# %%
data1.iloc[:,-1]
# Out:
# 0      5.0
# 1      4.9
# 2      4.5
# 3      4.0
# 4      4.5
# 5      4.5
# 6     10.0
# 7      5.0
# 8      5.0
# 9      4.8
# 10     5.0
# 11     5.0
# 12     5.0
# Name: Interest_in_ML, dtype: float64

# %%
data1.describe()
# Out:
#              Age  Interest_in_ML
# count  13.000000       13.000000
# mean   20.307692        5.169231
# std     0.854850        1.484017
# min    19.000000        4.000000
# 25%    20.000000        4.500000
# 50%    20.000000        5.000000
# 75%    21.000000        5.000000
# max    22.000000       10.000000

# %%
data1.describe(include = 'all')
# Out:
#             Name        Age  Interest_in_ML
# count         13  13.000000       13.000000
# unique        13        NaN             NaN
# top     Shrishti        NaN             NaN
# freq           1        NaN             NaN
# mean         NaN  20.307692        5.169231
# std          NaN   0.854850        1.484017
# min          NaN  19.000000        4.000000
# 25%          NaN  20.000000        4.500000
# 50%          NaN  20.000000        5.000000
# 75%          NaN  21.000000        5.000000
# max          NaN  22.000000       10.000000

# %%
data1.describe(include = 'object')
# Out:
#             Name
# count         13
# unique        13
# top     Shrishti
# freq           1

# %%
data1.describe()
# Out:
#              Age  Interest_in_ML
# count  13.000000       13.000000
# mean   20.307692        5.169231
# std     0.854850        1.484017
# min    19.000000        4.000000
# 25%    20.000000        4.500000
# 50%    20.000000        5.000000
# 75%    21.000000        5.000000
# max    22.000000       10.000000

# %%
data1.describe(include = 'object')
# Out:
#             Name
# count         13
# unique        13
# top     Shrishti
# freq           1

# %%
data1.describe(include = 'all')
# Out:
#             Name        Age  Interest_in_ML
# count         13  13.000000       13.000000
# unique        13        NaN             NaN
# top     Shrishti        NaN             NaN
# freq           1        NaN             NaN
# mean         NaN  20.307692        5.169231
# std          NaN   0.854850        1.484017
# min          NaN  19.000000        4.000000
# 25%          NaN  20.000000        4.500000
# 50%          NaN  20.000000        5.000000
# 75%          NaN  21.000000        5.000000
# max          NaN  22.000000       10.000000

# %%
data1
# Out:
#           Name  Age  Interest_in_ML
# 0     Abhishek   19             5.0
# 1       Arjun    21             4.9
# 2        Bipin   20             4.5
# 3       Deepak   20             4.0
# 4    Harjeevan   21             4.5
# 5        Karan   19             4.5
# 6       Meghna   22            10.0
# 7        Pooja   20             5.0
# 8       Rahul    21             5.0
# 9     Shrishti   20             4.8
# 10      Simran   20             5.0
# 11  Sudhanshu    21             5.0
# 12       Sunny   20             5.0

# %%
data1.Age.cumprod()
# Out:
# 0                    19
# 1                   399
# 2                  7980
# 3                159600
# 4               3351600
# 5              63680400
# 6            1400968800
# 7           28019376000
# 8          588406896000
# 9        11768137920000
# 10      235362758400000
# 11     4942617926400000
# 12    98852358528000000
# Name: Age, dtype: int64
