# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/Shreyas3108/May28thMLbatcj/blob/master/Untitled9.ipynb)

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv')

# %%
df.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.shape
# Out:
# (366, 24)

# %%
df.size
# Out:
# 8784

# %%
df.describe(include = 'all')
# Out:
#              Date  Location     MinTemp     MaxTemp    Rainfall  Evaporation  \
# count         366       366  366.000000  366.000000  366.000000   366.000000
# unique        366         1         NaN         NaN         NaN          NaN
# top     4/15/2008  Canberra         NaN         NaN         NaN          NaN
# freq            1       366         NaN         NaN         NaN          NaN
# mean          NaN       NaN    7.265574   20.550273    1.428415     4.521858
# std           NaN       NaN    6.025800    6.690516    4.225800     2.669383
# min           NaN       NaN   -5.300000    7.600000    0.000000     0.200000
# 25%           NaN       NaN    2.300000   15.025000    0.000000     2.200000
# 50%           NaN       NaN    7.450000   19.650000    0.000000     4.200000
# 75%           NaN       NaN   12.500000   25.500000    0.200000     6.400000
# max           NaN       NaN   20.900000   35.800000   39.800000    13.800000
#
# ...

# %%
df.isnull().sum()
# Out:
# Date              0
# Location          0
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
df = df.dropna(subset = ['WindDir9am'])

# %%
df.shape
# Out:
# (335, 24)

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (328, 24)

# %%
df.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# RainTomorrow     0
# dtype: int64

# %%
data = pd.read_csv('https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv') 

data = data.fillna(data.mean())

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# RainTomorrow     0
# dtype: int64

# %%
data['WindDir9am']
# Out:
# 0       SW
# 1        E
# 2        N
# 3      WNW
# 4      SSE
# 5       SE
# 6       SE
# 7       SE
# 8        E
# 9        S
# 10      SE
# 11       E
# 12       S
# 13     WNW
# 14       S
# 15      SE
# 16     WSW
# 17      SW
# 18     NNE
# 19     NNW
# 20       N
# 21     ENE
# 22       S
# 23     WSW
# 24     SSE
# 25       E
# 26       E
# 27       S
# 28      SE
# 29     SSW
#       ...
# 334    NNW
# 335     SW
# 336    NNW
# 337     NW
# 338    NNW
# 339    ENE
# 340      N
# 341    NNW
# 342    NNE
# 343      S
# 344    NNW
# 345    SSW
# 346    ENE
# 347     NE
# 348    NNE
# 349    SSE
# 350     SW
# 352      N
# 353      W
# 354     SE
# 355      S
# 356      S
# 357    SSE
# 358    SSE
# 359      N
# 361    SSE
# 362    NNW
# 363    ENE
# 364    SSW
# 365     NW
# Name: WindDir9am, Length: 331, dtype: object

# %%
data['WindDir9am'] = data.WindDir9am.replace(['n','s','e'],['N','S','E'])

# %%
data.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
dfg = data.groupby(by = 'WindDir9am').agg(['sum','mean'])

# %%
dfg
# Out:
#            MinTemp            MaxTemp            Rainfall            \
#                sum       mean     sum       mean      sum      mean
# WindDir9am
# E            218.6  10.930000   479.9  23.995000     35.6  1.780000
# ENE           81.3  10.162500   187.2  23.400000      3.4  0.425000
# ESE          261.7   9.024138   643.6  22.193103     22.0  0.758621
# N            251.4   8.380000   650.2  21.673333     57.0  1.900000
# NE            17.4   4.350000    82.7  20.675000      0.0  0.000000
# NNE           58.8   7.350000   188.3  23.537500     13.8  1.725000
# NNW          265.7   7.380556   718.6  19.961111     77.0  2.138889
# NW           224.5   7.483333   573.3  19.110000     64.2  2.140000
# S            195.7   7.526923   522.5  20.096154     67.2  2.584615
# SE           334.1   7.108511   994.0  21.148936     10.4  0.221277
# SSE          328.1   8.202500   830.7  20.767500     53.6  1.340000
# SSW           84.1   4.947059   327.2  19.247059      1.8  0.105882
# ...

# %%
dfg.shape
# Out:
# (16, 34)

# %%
dfg['Count'] = data.groupby(by = 'WindDir9am')['MinTemp'].agg(['count'])

# %%
dfg
# Out:
#            MinTemp            MaxTemp            Rainfall            \
#                sum       mean     sum       mean      sum      mean
# WindDir9am
# E            218.6  10.930000   479.9  23.995000     35.6  1.780000
# ENE           81.3  10.162500   187.2  23.400000      3.4  0.425000
# ESE          261.7   9.024138   643.6  22.193103     22.0  0.758621
# N            251.4   8.380000   650.2  21.673333     57.0  1.900000
# NE            17.4   4.350000    82.7  20.675000      0.0  0.000000
# NNE           58.8   7.350000   188.3  23.537500     13.8  1.725000
# NNW          265.7   7.380556   718.6  19.961111     77.0  2.138889
# NW           224.5   7.483333   573.3  19.110000     64.2  2.140000
# S            195.7   7.526923   522.5  20.096154     67.2  2.584615
# SE           334.1   7.108511   994.0  21.148936     10.4  0.221277
# SSE          328.1   8.202500   830.7  20.767500     53.6  1.340000
# SSW           84.1   4.947059   327.2  19.247059      1.8  0.105882
# ...

# %%
df['Location'].describe(include = 'all')
# Out:
# count          366
# unique           1
# top       Canberra
# freq           366
# Name: Location, dtype: object

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-d5ed7ae1-7326-4cde-baae-9fba2f9c328e" name="files[]" multiple disabled />
#      <output id="result-d5ed7ae1-7326-4cde-baae-9fba2f9c328e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Book1.xlsx to Book1.xlsx
# User uploaded file "Book1.xlsx" with length 9900 bytes

# %%
data1 = pd.read_excel('Book1.xlsx' , 0)

# %%
data1
# Out:
#           Name  Age  Interest_in_ML
# 0     Abhishek   19             5.0
# 1       Arjun    21             4.9
# 2        Bipin   20             4.5
# 3       Deepak   20             4.0
# 4    Harjeevan   21             4.5
# 5        Karan   19             4.5
# 6       Meghna   22            10.0
# 7        Pooja   20             5.0
# 8       Rahul    21             5.0
# 9     Shrishti   20             4.8
# 10      Simran   20             5.0
# 11  Sudhanshu    21             5.0
# 12       Sunny   20             5.0

# %%
data1.describe()
# Out:
#              Age  Interest_in_ML
# count  13.000000       13.000000
# mean   20.307692        5.169231
# std     0.854850        1.484017
# min    19.000000        4.000000
# 25%    20.000000        4.500000
# 50%    20.000000        5.000000
# 75%    21.000000        5.000000
# max    22.000000       10.000000

# %%
data1.loc[data1['Interest_in_ML'] <= 5]
# Out:
#           Name  Age  Interest_in_ML
# 0     Abhishek   19             5.0
# 1       Arjun    21             4.9
# 2        Bipin   20             4.5
# 3       Deepak   20             4.0
# 4    Harjeevan   21             4.5
# 5        Karan   19             4.5
# 7        Pooja   20             5.0
# 8       Rahul    21             5.0
# 9     Shrishti   20             4.8
# 10      Simran   20             5.0
# 11  Sudhanshu    21             5.0
# 12       Sunny   20             5.0

# %%
data1[data1['Interest_in_ML'] < 5.1]
# Out:
#           Name  Age  Interest_in_ML
# 0     Abhishek   19             5.0
# 1       Arjun    21             4.9
# 2        Bipin   20             4.5
# 3       Deepak   20             4.0
# 4    Harjeevan   21             4.5
# 5        Karan   19             4.5
# 7        Pooja   20             5.0
# 8       Rahul    21             5.0
# 9     Shrishti   20             4.8
# 10      Simran   20             5.0
# 11  Sudhanshu    21             5.0
# 12       Sunny   20             5.0

# %%
data2 = data1[data1['Name'] != 'Meghna']

# %%
data2.describe()
# Out:
#              Age  Interest_in_ML
# count  12.000000       12.000000
# mean   20.166667        4.766667
# std     0.717741        0.322866
# min    19.000000        4.000000
# 25%    20.000000        4.500000
# 50%    20.000000        4.950000
# 75%    21.000000        5.000000
# max    21.000000        5.000000

# %%
data1.loc[(data1['Name']!='Meghna') & (data1['Name']!='Harjeevan')]
# Out:
#           Name  Age  Interest_in_ML
# 0     Abhishek   19             5.0
# 1       Arjun    21             4.9
# 2        Bipin   20             4.5
# 3       Deepak   20             4.0
# 5        Karan   19             4.5
# 7        Pooja   20             5.0
# 8       Rahul    21             5.0
# 9     Shrishti   20             4.8
# 10      Simran   20             5.0
# 11  Sudhanshu    21             5.0
# 12       Sunny   20             5.0

# %%
data1.sum()
# Out:
# Name              AbhishekArjun BipinDeepakHarjeevanKaranMeghnaP...
# Age                                                             264
# Interest_in_ML                                                 67.2
# dtype: object

# %%
data1.iloc[1:3,:]
# Out:
#      Name  Age  Interest_in_ML
# 1  Arjun    21             4.9
# 2   Bipin   20             4.5

# %%
data1.iloc[:,:-1]
# Out:
#           Name  Age
# 0     Abhishek   19
# 1       Arjun    21
# 2        Bipin   20
# 3       Deepak   20
# 4    Harjeevan   21
# 5        Karan   19
# 6       Meghna   22
# 7        Pooja   20
# 8       Rahul    21
# 9     Shrishti   20
# 10      Simran   20
# 11  Sudhanshu    21
# 12       Sunny   20

# %%
data1.iloc[:,-1]
# Out:
# 0      5.0
# 1      4.9
# 2      4.5
# 3      4.0
# 4      4.5
# 5      4.5
# 6     10.0
# 7      5.0
# 8      5.0
# 9      4.8
# 10     5.0
# 11     5.0
# 12     5.0
# Name: Interest_in_ML, dtype: float64

# %%
data1.describe()
# Out:
#              Age  Interest_in_ML
# count  13.000000       13.000000
# mean   20.307692        5.169231
# std     0.854850        1.484017
# min    19.000000        4.000000
# 25%    20.000000        4.500000
# 50%    20.000000        5.000000
# 75%    21.000000        5.000000
# max    22.000000       10.000000

# %%
data1.describe(include = 'all')
# Out:
#             Name        Age  Interest_in_ML
# count         13  13.000000       13.000000
# unique        13        NaN             NaN
# top     Shrishti        NaN             NaN
# freq           1        NaN             NaN
# mean         NaN  20.307692        5.169231
# std          NaN   0.854850        1.484017
# min          NaN  19.000000        4.000000
# 25%          NaN  20.000000        4.500000
# 50%          NaN  20.000000        5.000000
# 75%          NaN  21.000000        5.000000
# max          NaN  22.000000       10.000000

# %%
data1.describe(include = 'object')
# Out:
#             Name
# count         13
# unique        13
# top     Shrishti
# freq           1

# %%
data1.describe()
# Out:
#              Age  Interest_in_ML
# count  13.000000       13.000000
# mean   20.307692        5.169231
# std     0.854850        1.484017
# min    19.000000        4.000000
# 25%    20.000000        4.500000
# 50%    20.000000        5.000000
# 75%    21.000000        5.000000
# max    22.000000       10.000000

# %%
data1.describe(include = 'object')
# Out:
#             Name
# count         13
# unique        13
# top     Shrishti
# freq           1

# %%
data1.describe(include = 'all')
# Out:
#             Name        Age  Interest_in_ML
# count         13  13.000000       13.000000
# unique        13        NaN             NaN
# top     Shrishti        NaN             NaN
# freq           1        NaN             NaN
# mean         NaN  20.307692        5.169231
# std          NaN   0.854850        1.484017
# min          NaN  19.000000        4.000000
# 25%          NaN  20.000000        4.500000
# 50%          NaN  20.000000        5.000000
# 75%          NaN  21.000000        5.000000
# max          NaN  22.000000       10.000000

# %%
data1
# Out:
#           Name  Age  Interest_in_ML
# 0     Abhishek   19             5.0
# 1       Arjun    21             4.9
# 2        Bipin   20             4.5
# 3       Deepak   20             4.0
# 4    Harjeevan   21             4.5
# 5        Karan   19             4.5
# 6       Meghna   22            10.0
# 7        Pooja   20             5.0
# 8       Rahul    21             5.0
# 9     Shrishti   20             4.8
# 10      Simran   20             5.0
# 11  Sudhanshu    21             5.0
# 12       Sunny   20             5.0

# %%
data1.Age.cumprod()
# Out:
# 0                    19
# 1                   399
# 2                  7980
# 3                159600
# 4               3351600
# 5              63680400
# 6            1400968800
# 7           28019376000
# 8          588406896000
# 9        11768137920000
# 10      235362758400000
# 11     4942617926400000
# 12    98852358528000000
# Name: Age, dtype: int64
